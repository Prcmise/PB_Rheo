# %% [markdown]
# # 流变性能预测 - 基于物理信息神经网络（PINN）的实现
#
# 本笔记本使用物理信息神经网络（Physics-Informed Neural Networks, PINN）来预测高分子材料的流变性能。相比传统的机器学习方法，PINN具有以下优势：
#
# 1. 结合物理约束：
#    - Cox-Merz规则
#    - Kramers-Kronig关系
#    - 储能损耗角物理约束
#    - 热力学约束
#
# 2. 改进的特征工程：
#    - WLF（Williams-Landel-Ferry）时温等效性
#    - 考虑分子量和温度的耦合效应
#    - 长宽比的非线性效应
#
# 3. 不确定性量化：
#    - 使用深度集成和Monte Carlo Dropout
#    - 提供预测的置信区间

# %%
# 导入所需的库
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, TensorDataset
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.special import gamma
from typing import Tuple, List
from collections import defaultdict

# 检查CUDA是否可用
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"使用设备: {device}")

# 设置随机种子以确保可重复性
RANDOM_SEED = 24
torch.manual_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(RANDOM_SEED)
    
# 设置全局参数
BATCH_SIZE = 64        # 增大批次大小
LEARNING_RATE = 5e-4   # 调整学习率
EPOCHS = 1000          # 增加训练轮数
PHYSICS_WEIGHT = 0.1  # 降低物理约束权重
MC_SAMPLES = 50        # Monte Carlo采样次数
# Out:
# 使用设备: cpu

# %%
# 数据加载和预处理
class RheologyDataset:
    def __init__(self, csv_path: str):
        """初始化数据集类
        
        Args:
            csv_path: PB_Data.csv的路径
        """
        # 读取数据
        self.df = pd.read_csv(csv_path)
        self.process_data()
        
    def process_data(self):
        """数据预处理和特征工程"""
        df = self.df
        
        # 计算tan_delta并设置权重
        df['tan_delta'] = df['G2_Pa'] / df['G1_Pa']
        df['data_weight'] = 1.0
        mask_outlier = (df['tan_delta'] < 0.1) | (df['tan_delta'] > 5)
        df.loc[mask_outlier, 'data_weight'] = 0.0
        
        # 基本特征工程
        df['aspect_ratio'] = df['Length_nm'] / df['Width_nm']
        df['log_freq'] = np.log10(df['Freq_rad_s'])
        
        # 分子量相关特征
        if 'Mw' in df.columns and 'Mn' in df.columns:
            df['PDI'] = df['Mw'] / df['Mn']  # 分子量分布指数
            df['log_Mw'] = np.log10(df['Mw'])
            df['log_Mn'] = np.log10(df['Mn'])
        else:
            # 如果没有分子量数据，添加空列
            df['Mw'] = 0
            df['Mn'] = 0
            df['PDI'] = 1
            df['log_Mw'] = 0
            df['log_Mn'] = 0
        
        # 浓度特征（如果存在）
        if 'c' in df.columns:
            df['log_c'] = np.log10(df['c'])
        else:
            df['c'] = 0
            df['log_c'] = 0
        
        # WLF时温等效性特征
        T_ref = 25  # 参考温度
        C1 = 8.86   # WLF参数
        C2 = 101.6  # WLF参数
        df['aT'] = 10 ** (-C1 * (df['Temp_C'] - T_ref) / (C2 + df['Temp_C'] - T_ref))
        df['reduced_freq'] = df['Freq_rad_s'] * df['aT']
        
        # 温度相关特征
        df['temp_inv'] = 1 / (df['Temp_C'] + 273.15)  # 开尔文温度的倒数
        df['T_x_aspect'] = df['Temp_C'] * df['aspect_ratio']
        
        # 对数转换目标变量（使用安全的对数转换）
        df['log_G1'] = np.log10(np.clip(df['G1_Pa'], 1e-10, None))
        df['log_G2'] = np.log10(np.clip(df['G2_Pa'], 1e-10, None))
        
        print("\n数据统计:")
        print("\nG1_Pa范围:", df['G1_Pa'].min(), "-", df['G1_Pa'].max())
        print("G2_Pa范围:", df['G2_Pa'].min(), "-", df['G2_Pa'].max())
        print("\nlog_G1范围:", df['log_G1'].min(), "-", df['log_G1'].max())
        print("log_G2范围:", df['log_G2'].min(), "-", df['log_G2'].max())
        
        # 定义特征列
        self.feature_cols = [
            'Length_nm', 'Width_nm', 'aspect_ratio', 'Temp_C', 
            'log_freq', 'temp_inv', 'T_x_aspect', 'aT',
            'log_Mw', 'log_Mn', 'PDI', 'log_c' 
        ]
        self.target_cols = ['log_G1', 'log_G2']
        
        # 数据标准化
        self.scaler_X = StandardScaler()
        self.scaler_y = StandardScaler()
        
        # 准备训练数据
        X = self.scaler_X.fit_transform(df[self.feature_cols])
        y = self.scaler_y.fit_transform(df[self.target_cols])
        
        # 保存数据权重
        self.data_weights = torch.FloatTensor(df['data_weight'].values).to(device)
        
        # 打印标准化参数
        print("\n特征标准化参数:")
        for name, scale, mean in zip(self.feature_cols, self.scaler_X.scale_, self.scaler_X.mean_):
            print(f"{name}: scale={scale:.4f}, mean={mean:.4f}")
            
        print("\n目标标准化参数:")
        for name, scale, mean in zip(self.target_cols, self.scaler_y.scale_, self.scaler_y.mean_):
            print(f"{name}: scale={scale:.4f}, mean={mean:.4f}")
        
        # 分割数据集
        X_train, X_val, y_train, y_val = train_test_split(
            X, y, test_size=0.2, random_state=RANDOM_SEED, stratify=None
        )
        
        # 获取相应的权重
        train_indices = np.arange(len(df))[:-len(y_val)]
        val_indices = np.arange(len(df))[-len(y_val):]
        train_weights = self.data_weights[train_indices]
        val_weights = self.data_weights[val_indices]
        
        # 转换为PyTorch张量
        self.X_train = torch.FloatTensor(X_train).to(device)
        self.y_train = torch.FloatTensor(y_train).to(device)
        self.X_val = torch.FloatTensor(X_val).to(device)
        self.y_val = torch.FloatTensor(y_val).to(device)
        self.train_weights = train_weights
        self.val_weights = val_weights
        
        # 创建数据加载器
        train_dataset = TensorDataset(self.X_train, self.y_train, self.train_weights)
        val_dataset = TensorDataset(self.X_val, self.y_val, self.val_weights)
        
        self.train_loader = DataLoader(
            train_dataset, batch_size=BATCH_SIZE, shuffle=True
        )
        self.val_loader = DataLoader(
            val_dataset, batch_size=BATCH_SIZE, shuffle=False
        )
        
    def inverse_transform_y(self, y_scaled):
        """将标准化的预测值转换回原始尺度"""
        if isinstance(y_scaled, torch.Tensor):
            y_scaled = y_scaled.cpu().detach().numpy()
        
        # 首先反标准化到对数空间
        y_log = self.scaler_y.inverse_transform(y_scaled)
        
        # 然后从对数空间转换到原始空间
        return np.power(10.0, y_log)

# 加载数据
dataset = RheologyDataset("PB_Data.csv")
print("\n数据集信息:")
print(f"训练集大小: {len(dataset.X_train)}")
print(f"验证集大小: {len(dataset.X_val)}")
print(f"\n特征列: {dataset.feature_cols}")
print(f"目标列: {dataset.target_cols}")
# Out:
# 数据统计:
#
# G1_Pa范围: 7.14e-07 - 785.8
# G2_Pa范围: 7.59e-06 - 186.69
#
# log_G1范围: -6.146301788223826 - 2.8953120244757873
# log_G2范围: -5.11975822410452 - 2.271121055704133
#
# 特征标准化参数:
# Length_nm: scale=97.3858, mean=111.0000
# Width_nm: scale=4.6933, mean=25.4513
# aspect_ratio: scale=4.7682, mean=4.8483
# Temp_C: scale=7.0711, mean=25.0000
# log_freq: scale=1.2018, mean=-0.0001
# temp_inv: scale=0.0001, mean=0.0034
# T_x_aspect: scale=128.5372, mean=121.2069
# aT: scale=3.4040, mean=2.7386
# log_Mw: scale=0.3265, mean=6.6789
# log_Mn: scale=0.3087, mean=6.6896
# PDI: scale=0.0813, mean=0.9797
# log_c: scale=1.0000, mean=-1.2218
#
# 目标标准化参数:
# log_G1: scale=2.0969, mean=0.5570
# log_G2: scale=1.2305, mean=0.8273
#
# 数据集信息:
# 训练集大小: 1500
# 验证集大小: 375
#
# 特征列: ['Length_nm', 'Width_nm', 'aspect_ratio', 'Temp_C', 'log_freq', 'temp_inv', 'T_x_aspect', 'aT', 'log_Mw', 'log_Mn', 'PDI', 'log_c']
# 目标列: ['log_G1', 'log_G2']

# %%
class RheologyPINN(nn.Module):
    def __init__(self, input_dim: int, hidden_dim: int = 256, dropout_rate: float = 0.1):
        """初始化PINN模型
        
        Args:
            input_dim: 输入特征维度
            hidden_dim: 隐藏层维度
            dropout_rate: Dropout比率，用于不确定性估计
        """
        super(RheologyPINN, self).__init__()
        
        # 共享编码器网络（更深层次）
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.GELU(),  # 使用GELU激活函数
            nn.Dropout(dropout_rate),
            
            nn.Linear(hidden_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout_rate),
            
            nn.Linear(hidden_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout_rate),
            
            nn.Linear(hidden_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout_rate)
        )
        
        # G'预测分支（专门的结构）
        self.g_prime_branch = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim//2),
            nn.BatchNorm1d(hidden_dim//2),
            nn.GELU(),
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim//2, hidden_dim//4),
            nn.BatchNorm1d(hidden_dim//4),
            nn.GELU(),
            nn.Linear(hidden_dim//4, 1)
        )
        
        # G"预测分支
        self.g_double_prime_branch = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim//2),
            nn.BatchNorm1d(hidden_dim//2),
            nn.GELU(),
            nn.Dropout(dropout_rate),
            nn.Linear(hidden_dim//2, hidden_dim//4),
            nn.BatchNorm1d(hidden_dim//4),
            nn.GELU(),
            nn.Linear(hidden_dim//4, 1)
        )
        
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # 通过编码器
        encoded = self.encoder(x)
        
        # 预测G'和G"
        g_prime = self.g_prime_branch(encoded)
        g_double_prime = self.g_double_prime_branch(encoded)
        
        return torch.cat([g_prime, g_double_prime], dim=1)
    
    def predict_with_uncertainty(self, x: torch.Tensor, mc_samples: int = 100) -> Tuple[torch.Tensor, torch.Tensor]:
        """使用Monte Carlo Dropout进行带不确定性的预测"""
        self.train()  # 启用dropout
        predictions = []
        
        with torch.no_grad():
            for _ in range(mc_samples):
                pred = self(x)
                predictions.append(pred)
                
        predictions = torch.stack(predictions)
        mean_pred = predictions.mean(dim=0)
        std_pred = predictions.std(dim=0)
        
        return mean_pred, std_pred
    
    def physics_loss(self, x_batch: torch.Tensor, y_pred: torch.Tensor, dataset: RheologyDataset) -> Tuple[torch.Tensor, dict]:
        """计算物理约束损失
        
        Returns:
            total_physics_loss: 总物理约束损失
            loss_components: 各组分损失的字典
        """
        # 获取频率相关参数（避免numpy转换）
        freq_idx = dataset.feature_cols.index('log_freq')
        log_freq = x_batch[:, freq_idx] * dataset.scaler_X.scale_[freq_idx] + dataset.scaler_X.mean_[freq_idx]
        freq = torch.pow(10.0, log_freq)
        
        # 反标准化预测值（保持在对数空间）
        y_std = torch.tensor(dataset.scaler_y.scale_).to(device)
        y_mean = torch.tensor(dataset.scaler_y.mean_).to(device)
        log_g_prime = y_pred[:, 0] * y_std[0] + y_mean[0]
        log_g_double_prime = y_pred[:, 1] * y_std[1] + y_mean[1]
        
        # 转换到线性空间
        g_prime = torch.pow(10.0, log_g_prime)
        g_double_prime = torch.pow(10.0, log_g_double_prime)
        
        # 1. 改进的Cox-Merz规则约束（特别关注低频区域）
        log_complex_viscosity = torch.log10(torch.sqrt(g_prime**2 + g_double_prime**2) / freq + 1e-10)
        visc_diff = log_complex_viscosity[1:] - log_complex_viscosity[:-1]
        # 在低频区域修改权重
        low_freq_mask = freq[1:] < 1.0
        weighted_visc_diff = torch.where(low_freq_mask, visc_diff * 2.0, visc_diff)
        cox_merz_loss = torch.mean(torch.relu(-weighted_visc_diff))
        
        # 2. 储能损耗角物理约束 (0 < δ < π/2)
        loss_tangent = g_double_prime / (g_prime + 1e-10)
        angle_loss = torch.mean(torch.relu(-loss_tangent) + 
                              torch.relu(loss_tangent - torch.tensor(np.pi/2).to(device)))
        
        # 3. 平滑性约束和单调性约束
        # 计算G'和G"的一阶导数（在对数空间中）
        log_g_prime_grad = log_g_prime[1:] - log_g_prime[:-1]
        log_g_double_prime_grad = log_g_double_prime[1:] - log_g_double_prime[:-1]
        
        # 单调递增约束（斜率应为正）
        monotonicity_loss = (torch.mean(torch.relu(-log_g_prime_grad)) + 
                           torch.mean(torch.relu(-log_g_double_prime_grad))) * 4.0
        
        # 平滑性约束（二阶导数的大小）
        g_prime_smoothness = torch.mean(torch.abs(log_g_prime_grad[1:] - log_g_prime_grad[:-1]))
        g_double_prime_smoothness = torch.mean(torch.abs(log_g_double_prime_grad[1:] - log_g_double_prime_grad[:-1]))
        smoothness_loss = g_prime_smoothness + g_double_prime_smoothness
        
        # 4. 相对关系约束（避免G'和G"的交叉突变）
        rel_diff = (log_g_prime - log_g_double_prime)[1:] - (log_g_prime - log_g_double_prime)[:-1]
        rel_smoothness_loss = torch.mean(torch.abs(rel_diff))
        
        # 5. 热力学约束：G' > 0 和 G" > 0（在对数空间中）
        thermo_loss = torch.mean(torch.relu(-log_g_prime) + torch.relu(-log_g_double_prime))
        
        # 6. 低频区域特殊处理
        low_freq_mask = freq < 1.0
        low_freq_scaling = torch.where(low_freq_mask, 
                                     torch.ones_like(freq) * 2.0,
                                     torch.ones_like(freq))
        
        # 组合所有物理损失
        loss_components = {
            'cox_merz': cox_merz_loss * 0.15,
            'angle': angle_loss * 0.15,
            'monotonicity': monotonicity_loss * 0.2,  # 添加单调性约束
            'smoothness': smoothness_loss * 0.2,
            'rel_smoothness': rel_smoothness_loss * 0.2,
            'thermo': thermo_loss * 0.1
        }
        
        total_physics_loss = sum(loss_components.values())
        
        return total_physics_loss, loss_components

# 初始化模型
model = RheologyPINN(input_dim=len(dataset.feature_cols)).to(device)
print("\nPINN模型结构:")
print(model)
# Out:
# PINN模型结构:
# RheologyPINN(
#   (encoder): Sequential(
#     (0): Linear(in_features=12, out_features=256, bias=True)
#     (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Linear(in_features=256, out_features=256, bias=True)
#     (5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): GELU(approximate='none')
#     (7): Dropout(p=0.1, inplace=False)
#     (8): Linear(in_features=256, out_features=256, bias=True)
#     (9): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): GELU(approximate='none')
#     (11): Dropout(p=0.1, inplace=False)
#     (12): Linear(in_features=256, out_features=256, bias=True)
#     (13): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): GELU(approximate='none')
#     (15): Dropout(p=0.1, inplace=False)
#   )
#   (g_prime_branch): Sequential(
#     (0): Linear(in_features=256, out_features=128, bias=True)
#     (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): GELU(approximate='none')
#     (7): Linear(in_features=64, out_features=1, bias=True)
#   )
#   (g_double_prime_branch): Sequential(
#     (0): Linear(in_features=256, out_features=128, bias=True)
#     (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): GELU(approximate='none')
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): GELU(approximate='none')
#     (7): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %%
# 定义训练函数
def train_model(model: RheologyPINN, 
                dataset: RheologyDataset,
                epochs: int,
                physics_weight: float) -> Tuple[List[float], List[float]]:
    """训练PINN模型
    
    Args:
        model: PINN模型
        dataset: 数据集对象
        epochs: 训练轮数
        physics_weight: 物理约束损失权重
        
    Returns:
        train_losses: 训练损失历史
        val_losses: 验证损失历史
    """
    # 优化器设置
    optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.OneCycleLR(optimizer, max_lr=LEARNING_RATE,
                                            epochs=epochs,
                                            steps_per_epoch=len(dataset.train_loader))
    
    # 损失函数
    mse_loss = nn.MSELoss(reduction='none')  # 使用'none'以支持样本权重
    
    # 记录训练过程
    train_losses = []
    val_losses = []
    train_physics_losses = []
    train_components_losses = defaultdict(list)
    best_val_loss = float('inf')
    best_model_state = None
    patience_counter = 0
    max_patience = 50
    
    print("\n开始训练...")
    for epoch in range(epochs):
        # 训练阶段
        model.train()
        epoch_losses = []
        epoch_g_prime_losses = []
        epoch_g_double_prime_losses = []
        epoch_physics_losses = []
        epoch_components_losses = defaultdict(list)
        
        for batch_X, batch_y, batch_weights in dataset.train_loader:
            optimizer.zero_grad()
            
            # 前向传播
            y_pred = model(batch_X)
            
            # 分别计算G'和G"的损失（带权重）
            g_prime_losses = mse_loss(y_pred[:, 0], batch_y[:, 0])
            g_double_prime_losses = mse_loss(y_pred[:, 1], batch_y[:, 1])
            
            # 应用样本权重
            g_prime_loss = (g_prime_losses * batch_weights).mean()
            g_double_prime_loss = (g_double_prime_losses * batch_weights).mean()
            
            # 数据损失（加权组合）
            data_loss = 0.6 * g_prime_loss + 0.4 * g_double_prime_loss
            
            # 物理约束损失
            physics_loss, components_losses = model.physics_loss(batch_X, y_pred, dataset)
            
            # 动态权重计算
            current_step = epoch * len(dataset.train_loader) + len(epoch_losses)
            total_steps = epochs * len(dataset.train_loader)
            # 使用余弦退火调整物理约束权重
            physics_weight_dynamic = physics_weight * (
                1 + np.cos(np.pi * current_step / total_steps)
            ) / 2
            
            # 总损失
            total_loss = data_loss + physics_weight_dynamic * physics_loss
            
            # 反向传播
            total_loss.backward()
            
            # 梯度裁剪（按范数）
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            
            optimizer.step()
            scheduler.step()
            
            # 记录损失
            epoch_losses.append(total_loss.item())
            epoch_g_prime_losses.append(g_prime_loss.item())
            epoch_g_double_prime_losses.append(g_double_prime_loss.item())
            epoch_physics_losses.append(physics_loss.item())
            
            # 记录各组分损失
            for name, loss in components_losses.items():
                epoch_components_losses[name].append(loss.item())
        
        # 计算平均损失
        avg_train_loss = np.mean(epoch_losses)
        avg_physics_loss = np.mean(epoch_physics_losses)
        avg_components_losses = {name: np.mean(losses) 
                               for name, losses in epoch_components_losses.items()}
        
        train_losses.append(avg_train_loss)
        train_physics_losses.append(avg_physics_loss)
        for name, avg_loss in avg_components_losses.items():
            train_components_losses[name].append(avg_loss)
        
        # 验证阶段
        model.eval()
        val_epoch_losses = []
        val_physics_losses = []
        
        with torch.no_grad():
            for batch_X, batch_y, batch_weights in dataset.val_loader:
                y_pred = model(batch_X)
                
                # 计算加权验证损失
                val_g_prime_losses = mse_loss(y_pred[:, 0], batch_y[:, 0])
                val_g_double_prime_losses = mse_loss(y_pred[:, 1], batch_y[:, 1])
                
                val_g_prime_loss = (val_g_prime_losses * batch_weights).mean()
                val_g_double_prime_loss = (val_g_double_prime_losses * batch_weights).mean()
                
                val_data_loss = 0.6 * val_g_prime_loss + 0.4 * val_g_double_prime_loss
                val_physics_loss, _ = model.physics_loss(batch_X, y_pred, dataset)
                
                val_total_loss = val_data_loss + physics_weight_dynamic * val_physics_loss
                val_epoch_losses.append(val_total_loss.item())
                val_physics_losses.append(val_physics_loss.item())
        
        avg_val_loss = np.mean(val_epoch_losses)
        avg_val_physics_loss = np.mean(val_physics_losses)
        val_losses.append(avg_val_loss)
        
        # 保存最佳模型
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_model_state = model.state_dict().copy()
            patience_counter = 0
        else:
            patience_counter += 1
        
        # 提前停止检查
        if patience_counter >= max_patience:
            print(f'\n提前停止! 验证损失在{max_patience}轮内没有改善.')
            break
        
        # 打印训练进度
        if (epoch + 1) % 10 == 0:
            print(f'Epoch [{epoch+1}/{epochs}]')
            print(f'Train - Total: {avg_train_loss:.4f}, Physics: {avg_physics_loss:.4f}')
            print('Physics Components:')
            for name, avg_loss in avg_components_losses.items():
                print(f'  {name}: {avg_loss:.4f}')
            print(f'Val   - Total: {avg_val_loss:.4f}, Physics: {avg_val_physics_loss:.4f}')
            print(f'LR: {scheduler.get_last_lr()[0]:.6f}')
    
    # 加载最佳模型
    model.load_state_dict(best_model_state)
    
    # 绘制详细的训练历史
    plt.figure(figsize=(15, 10))
    
    # 总损失曲线
    plt.subplot(2, 2, 1)
    plt.plot(train_losses, label='Train Total')
    plt.plot(val_losses, label='Val Total')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Total Loss')
    plt.legend()
    plt.grid(True)
    
    # 物理约束损失曲线
    plt.subplot(2, 2, 2)
    plt.plot(train_physics_losses, label='Physics Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Physics Constraint Loss')
    plt.legend()
    plt.grid(True)
    
    # 各组分物理约束损失
    plt.subplot(2, 2, 3)
    for name, losses in train_components_losses.items():
        plt.plot(losses, label=name)
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Physics Components Losses')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()
    
    return train_losses, val_losses

# 训练模型
train_losses, val_losses = train_model(model, dataset, EPOCHS, PHYSICS_WEIGHT)
# Out:
# 开始训练...
# Epoch [10/1000]
# Train - Total: 0.6553, Physics: 2.1633
# Physics Components:
#   cox_merz: 0.1147
#   angle: 0.4937
#   monotonicity: 0.7543
#   smoothness: 0.6512
#   rel_smoothness: 0.1287
#   thermo: 0.0205
# Val   - Total: 0.5805, Physics: 1.7376
# LR: 0.000021
# Epoch [20/1000]
# Train - Total: 0.5748, Physics: 2.0996
# Physics Components:
#   cox_merz: 0.1271
#   angle: 0.1796
#   monotonicity: 0.8804
#   smoothness: 0.7737
#   rel_smoothness: 0.1103
#   thermo: 0.0285
# Val   - Total: 0.5234, Physics: 1.8678
# LR: 0.000025
# Epoch [30/1000]
# Train - Total: 0.5350, Physics: 2.0843
# Physics Components:
#   cox_merz: 0.1234
#   angle: 0.1371
#   monotonicity: 0.8989
#   smoothness: 0.7886
#   rel_smoothness: 0.1054
#   thermo: 0.0309
# Val   - Total: 0.5012, Physics: 1.9064
# LR: 0.000032
# Epoch [40/1000]
# Train - Total: 0.5093, Physics: 2.0997
# Physics Components:
#   cox_merz: 0.1324
#   angle: 0.1099
#   monotonicity: 0.9166
#   smoothness: 0.8073
#   rel_smoothness: 0.0989
#   thermo: 0.0346
# Val   - Total: 0.4872, Physics: 1.8994
# LR: 0.000041
# Epoch [50/1000]
# Train - Total: 0.4746, Physics: 2.0961
# Physics Components:
#   cox_merz: 0.1311
#   angle: 0.0927
#   monotonicity: 0.9290
#   smoothness: 0.8177
#   rel_smoothness: 0.0892
#   thermo: 0.0364
# Val   - Total: 0.4620, Physics: 2.0058
# LR: 0.000052
# Epoch [60/1000]
# Train - Total: 0.4535, Physics: 2.1513
# Physics Components:
#   cox_merz: 0.1300
#   angle: 0.1049
#   monotonicity: 0.9457
#   smoothness: 0.8393
#   rel_smoothness: 0.0904
#   thermo: 0.0410
# Val   - Total: 0.4454, Physics: 2.1075
# LR: 0.000066
# Epoch [70/1000]
# Train - Total: 0.4268, Physics: 2.0748
# Physics Components:
#   cox_merz: 0.1333
#   angle: 0.0827
#   monotonicity: 0.9159
#   smoothness: 0.8167
#   rel_smoothness: 0.0847
#   thermo: 0.0415
# Val   - Total: 0.4414, Physics: 2.2288
# LR: 0.000082
# Epoch [80/1000]
# Train - Total: 0.4176, Physics: 2.3070
# Physics Components:
#   cox_merz: 0.1414
#   angle: 0.0924
#   monotonicity: 1.0161
#   smoothness: 0.9269
#   rel_smoothness: 0.0842
#   thermo: 0.0459
# Val   - Total: 0.4259, Physics: 2.2763
# LR: 0.000099
# Epoch [90/1000]
# Train - Total: 0.4077, Physics: 2.2095
# Physics Components:
#   cox_merz: 0.1384
#   angle: 0.1020
#   monotonicity: 0.9694
#   smoothness: 0.8723
#   rel_smoothness: 0.0831
#   thermo: 0.0442
# Val   - Total: 0.4305, Physics: 2.2958
# LR: 0.000119
# Epoch [100/1000]
# Train - Total: 0.4028, Physics: 2.2110
# Physics Components:
#   cox_merz: 0.1382
#   angle: 0.0825
#   monotonicity: 0.9873
#   smoothness: 0.8787
#   rel_smoothness: 0.0785
#   thermo: 0.0458
# Val   - Total: 0.4196, Physics: 2.2059
# LR: 0.000140
# Epoch [110/1000]
# Train - Total: 0.3978, Physics: 2.2069
# Physics Components:
#   cox_merz: 0.1381
#   angle: 0.0867
#   monotonicity: 0.9812
#   smoothness: 0.8750
#   rel_smoothness: 0.0797
#   thermo: 0.0462
# Val   - Total: 0.4141, Physics: 2.3677
# LR: 0.000162
# Epoch [120/1000]
# Train - Total: 0.3934, Physics: 2.2609
# Physics Components:
#   cox_merz: 0.1428
#   angle: 0.1068
#   monotonicity: 0.9892
#   smoothness: 0.8945
#   rel_smoothness: 0.0811
#   thermo: 0.0465
# Val   - Total: 0.4156, Physics: 2.2680
# LR: 0.000186
# Epoch [130/1000]
# Train - Total: 0.3964, Physics: 2.2129
# Physics Components:
#   cox_merz: 0.1407
#   angle: 0.0873
#   monotonicity: 0.9876
#   smoothness: 0.8770
#   rel_smoothness: 0.0756
#   thermo: 0.0447
# Val   - Total: 0.4184, Physics: 2.2278
# LR: 0.000210
# Epoch [140/1000]
# Train - Total: 0.3856, Physics: 2.2410
# Physics Components:
#   cox_merz: 0.1369
#   angle: 0.1001
#   monotonicity: 0.9813
#   smoothness: 0.8954
#   rel_smoothness: 0.0807
#   thermo: 0.0466
# Val   - Total: 0.4103, Physics: 2.3275
# LR: 0.000235
# Epoch [150/1000]
# Train - Total: 0.3749, Physics: 2.2766
# Physics Components:
#   cox_merz: 0.1432
#   angle: 0.0979
#   monotonicity: 1.0043
#   smoothness: 0.9057
#   rel_smoothness: 0.0773
#   thermo: 0.0481
# Val   - Total: 0.4043, Physics: 2.3123
# LR: 0.000260
# Epoch [160/1000]
# Train - Total: 0.3914, Physics: 2.2901
# Physics Components:
#   cox_merz: 0.1436
#   angle: 0.0935
#   monotonicity: 1.0143
#   smoothness: 0.9131
#   rel_smoothness: 0.0779
#   thermo: 0.0477
# Val   - Total: 0.4102, Physics: 2.3998
# LR: 0.000285
# Epoch [170/1000]
# Train - Total: 0.3784, Physics: 2.1897
# Physics Components:
#   cox_merz: 0.1394
#   angle: 0.0990
#   monotonicity: 0.9659
#   smoothness: 0.8607
#   rel_smoothness: 0.0770
#   thermo: 0.0476
# Val   - Total: 0.4048, Physics: 2.4114
# LR: 0.000310
# Epoch [180/1000]
# Train - Total: 0.3662, Physics: 2.2933
# Physics Components:
#   cox_merz: 0.1423
#   angle: 0.0998
#   monotonicity: 1.0068
#   smoothness: 0.9160
#   rel_smoothness: 0.0784
#   thermo: 0.0500
# Val   - Total: 0.4027, Physics: 2.3670
# LR: 0.000334
# Epoch [190/1000]
# Train - Total: 0.3601, Physics: 2.2480
# Physics Components:
#   cox_merz: 0.1419
#   angle: 0.0987
#   monotonicity: 0.9882
#   smoothness: 0.8933
#   rel_smoothness: 0.0784
#   thermo: 0.0476
# Val   - Total: 0.4006, Physics: 2.2690
# LR: 0.000358
# Epoch [200/1000]
# Train - Total: 0.3718, Physics: 2.2990
# Physics Components:
#   cox_merz: 0.1471
#   angle: 0.1026
#   monotonicity: 1.0125
#   smoothness: 0.9105
#   rel_smoothness: 0.0797
#   thermo: 0.0466
# Val   - Total: 0.3912, Physics: 2.4571
# LR: 0.000380
# Epoch [210/1000]
# Train - Total: 0.3535, Physics: 2.2943
# Physics Components:
#   cox_merz: 0.1440
#   angle: 0.1013
#   monotonicity: 1.0129
#   smoothness: 0.9053
#   rel_smoothness: 0.0815
#   thermo: 0.0492
# Val   - Total: 0.3910, Physics: 2.4701
# LR: 0.000401
# Epoch [220/1000]
# Train - Total: 0.3596, Physics: 2.3018
# Physics Components:
#   cox_merz: 0.1428
#   angle: 0.1010
#   monotonicity: 1.0190
#   smoothness: 0.9107
#   rel_smoothness: 0.0803
#   thermo: 0.0480
# Val   - Total: 0.3905, Physics: 2.4429
# LR: 0.000421
# Epoch [230/1000]
# Train - Total: 0.3577, Physics: 2.3602
# Physics Components:
#   cox_merz: 0.1466
#   angle: 0.1040
#   monotonicity: 1.0370
#   smoothness: 0.9418
#   rel_smoothness: 0.0817
#   thermo: 0.0492
# Val   - Total: 0.3849, Physics: 2.4032
# LR: 0.000438
# Epoch [240/1000]
# Train - Total: 0.3496, Physics: 2.3216
# Physics Components:
#   cox_merz: 0.1450
#   angle: 0.1117
#   monotonicity: 1.0192
#   smoothness: 0.9120
#   rel_smoothness: 0.0828
#   thermo: 0.0508
# Val   - Total: 0.3823, Physics: 2.3934
# LR: 0.000454
# Epoch [250/1000]
# Train - Total: 0.3500, Physics: 2.3452
# Physics Components:
#   cox_merz: 0.1415
#   angle: 0.1029
#   monotonicity: 1.0376
#   smoothness: 0.9329
#   rel_smoothness: 0.0819
#   thermo: 0.0483
# Val   - Total: 0.3832, Physics: 2.4648
# LR: 0.000468
# Epoch [260/1000]
# Train - Total: 0.3549, Physics: 2.3955
# Physics Components:
#   cox_merz: 0.1432
#   angle: 0.1247
#   monotonicity: 1.0443
#   smoothness: 0.9482
#   rel_smoothness: 0.0860
#   thermo: 0.0492
# Val   - Total: 0.3795, Physics: 2.4447
# LR: 0.000479
# Epoch [270/1000]
# Train - Total: 0.3390, Physics: 2.4062
# Physics Components:
#   cox_merz: 0.1445
#   angle: 0.1162
#   monotonicity: 1.0604
#   smoothness: 0.9497
#   rel_smoothness: 0.0864
#   thermo: 0.0492
# Val   - Total: 0.3777, Physics: 2.4069
# LR: 0.000488
# Epoch [280/1000]
# Train - Total: 0.3349, Physics: 2.4194
# Physics Components:
#   cox_merz: 0.1433
#   angle: 0.1318
#   monotonicity: 1.0615
#   smoothness: 0.9440
#   rel_smoothness: 0.0863
#   thermo: 0.0525
# Val   - Total: 0.3739, Physics: 2.4077
# LR: 0.000495
# Epoch [290/1000]
# Train - Total: 0.3321, Physics: 2.4020
# Physics Components:
#   cox_merz: 0.1460
#   angle: 0.1308
#   monotonicity: 1.0480
#   smoothness: 0.9390
#   rel_smoothness: 0.0847
#   thermo: 0.0535
# Val   - Total: 0.3688, Physics: 2.4164
# LR: 0.000499
# Epoch [300/1000]
# Train - Total: 0.3314, Physics: 2.4257
# Physics Components:
#   cox_merz: 0.1444
#   angle: 0.1250
#   monotonicity: 1.0638
#   smoothness: 0.9510
#   rel_smoothness: 0.0890
#   thermo: 0.0526
# Val   - Total: 0.3670, Physics: 2.5850
# LR: 0.000500
# Epoch [310/1000]
# Train - Total: 0.3417, Physics: 2.4389
# Physics Components:
#   cox_merz: 0.1459
#   angle: 0.1298
#   monotonicity: 1.0673
#   smoothness: 0.9574
#   rel_smoothness: 0.0894
#   thermo: 0.0492
# Val   - Total: 0.3622, Physics: 2.5001
# LR: 0.000500
# Epoch [320/1000]
# Train - Total: 0.3178, Physics: 2.4231
# Physics Components:
#   cox_merz: 0.1461
#   angle: 0.1353
#   monotonicity: 1.0511
#   smoothness: 0.9465
#   rel_smoothness: 0.0920
#   thermo: 0.0520
# Val   - Total: 0.3522, Physics: 2.5139
# LR: 0.000499
# Epoch [330/1000]
# Train - Total: 0.3095, Physics: 2.4600
# Physics Components:
#   cox_merz: 0.1444
#   angle: 0.1393
#   monotonicity: 1.0732
#   smoothness: 0.9561
#   rel_smoothness: 0.0913
#   thermo: 0.0558
# Val   - Total: 0.3514, Physics: 2.5277
# LR: 0.000498
# Epoch [340/1000]
# Train - Total: 0.3206, Physics: 2.5115
# Physics Components:
#   cox_merz: 0.1503
#   angle: 0.1507
#   monotonicity: 1.0832
#   smoothness: 0.9802
#   rel_smoothness: 0.0900
#   thermo: 0.0571
# Val   - Total: 0.3523, Physics: 2.4761
# LR: 0.000496
# Epoch [350/1000]
# Train - Total: 0.3088, Physics: 2.4577
# Physics Components:
#   cox_merz: 0.1453
#   angle: 0.1474
#   monotonicity: 1.0616
#   smoothness: 0.9586
#   rel_smoothness: 0.0922
#   thermo: 0.0526
# Val   - Total: 0.3452, Physics: 2.6680
# LR: 0.000494
# Epoch [360/1000]
# Train - Total: 0.3035, Physics: 2.4025
# Physics Components:
#   cox_merz: 0.1464
#   angle: 0.1371
#   monotonicity: 1.0465
#   smoothness: 0.9298
#   rel_smoothness: 0.0914
#   thermo: 0.0513
# Val   - Total: 0.3459, Physics: 2.6737
# LR: 0.000491
# Epoch [370/1000]
# Train - Total: 0.3025, Physics: 2.6019
# Physics Components:
#   cox_merz: 0.1528
#   angle: 0.1628
#   monotonicity: 1.1147
#   smoothness: 1.0178
#   rel_smoothness: 0.0970
#   thermo: 0.0568
# Val   - Total: 0.3385, Physics: 2.5743
# LR: 0.000488
# Epoch [380/1000]
# Train - Total: 0.2900, Physics: 2.5194
# Physics Components:
#   cox_merz: 0.1486
#   angle: 0.1779
#   monotonicity: 1.0691
#   smoothness: 0.9678
#   rel_smoothness: 0.0998
#   thermo: 0.0562
# Val   - Total: 0.3370, Physics: 2.6901
# LR: 0.000484
# Epoch [390/1000]
# Train - Total: 0.2861, Physics: 2.4918
# Physics Components:
#   cox_merz: 0.1413
#   angle: 0.1586
#   monotonicity: 1.0742
#   smoothness: 0.9642
#   rel_smoothness: 0.0970
#   thermo: 0.0566
# Val   - Total: 0.3293, Physics: 2.6990
# LR: 0.000480
# Epoch [400/1000]
# Train - Total: 0.2920, Physics: 2.5657
# Physics Components:
#   cox_merz: 0.1492
#   angle: 0.1667
#   monotonicity: 1.1025
#   smoothness: 0.9942
#   rel_smoothness: 0.0949
#   thermo: 0.0583
# Val   - Total: 0.3238, Physics: 2.5916
# LR: 0.000475
# Epoch [410/1000]
# Train - Total: 0.2818, Physics: 2.6430
# Physics Components:
#   cox_merz: 0.1471
#   angle: 0.1699
#   monotonicity: 1.1399
#   smoothness: 1.0304
#   rel_smoothness: 0.1010
#   thermo: 0.0547
# Val   - Total: 0.3219, Physics: 2.5747
# LR: 0.000470
# Epoch [420/1000]
# Train - Total: 0.2766, Physics: 2.5645
# Physics Components:
#   cox_merz: 0.1593
#   angle: 0.1661
#   monotonicity: 1.1062
#   smoothness: 0.9794
#   rel_smoothness: 0.0980
#   thermo: 0.0555
# Val   - Total: 0.3149, Physics: 2.6386
# LR: 0.000465
# Epoch [430/1000]
# Train - Total: 0.2705, Physics: 2.6699
# Physics Components:
#   cox_merz: 0.1500
#   angle: 0.2109
#   monotonicity: 1.1296
#   smoothness: 1.0112
#   rel_smoothness: 0.1048
#   thermo: 0.0634
# Val   - Total: 0.3168, Physics: 2.7324
# LR: 0.000459
# Epoch [440/1000]
# Train - Total: 0.2648, Physics: 2.6457
# Physics Components:
#   cox_merz: 0.1482
#   angle: 0.2123
#   monotonicity: 1.1187
#   smoothness: 1.0024
#   rel_smoothness: 0.1035
#   thermo: 0.0606
# Val   - Total: 0.3061, Physics: 2.6684
# LR: 0.000452
# Epoch [450/1000]
# Train - Total: 0.2614, Physics: 2.6840
# Physics Components:
#   cox_merz: 0.1489
#   angle: 0.2007
#   monotonicity: 1.1379
#   smoothness: 1.0307
#   rel_smoothness: 0.1056
#   thermo: 0.0602
# Val   - Total: 0.3020, Physics: 2.6695
# LR: 0.000445
# Epoch [460/1000]
# Train - Total: 0.2672, Physics: 2.6669
# Physics Components:
#   cox_merz: 0.1562
#   angle: 0.1973
#   monotonicity: 1.1260
#   smoothness: 1.0206
#   rel_smoothness: 0.1063
#   thermo: 0.0606
# Val   - Total: 0.3016, Physics: 2.8397
# LR: 0.000438
# Epoch [470/1000]
# Train - Total: 0.2529, Physics: 2.6980
# Physics Components:
#   cox_merz: 0.1541
#   angle: 0.2228
#   monotonicity: 1.1314
#   smoothness: 1.0203
#   rel_smoothness: 0.1104
#   thermo: 0.0591
# Val   - Total: 0.2910, Physics: 2.7811
# LR: 0.000431
# Epoch [480/1000]
# Train - Total: 0.2525, Physics: 2.7895
# Physics Components:
#   cox_merz: 0.1553
#   angle: 0.2363
#   monotonicity: 1.1699
#   smoothness: 1.0552
#   rel_smoothness: 0.1117
#   thermo: 0.0610
# Val   - Total: 0.2879, Physics: 2.7448
# LR: 0.000423
# Epoch [490/1000]
# Train - Total: 0.2375, Physics: 2.7522
# Physics Components:
#   cox_merz: 0.1501
#   angle: 0.2529
#   monotonicity: 1.1395
#   smoothness: 1.0336
#   rel_smoothness: 0.1140
#   thermo: 0.0621
# Val   - Total: 0.2838, Physics: 2.8952
# LR: 0.000414
# Epoch [500/1000]
# Train - Total: 0.2407, Physics: 2.8467
# Physics Components:
#   cox_merz: 0.1563
#   angle: 0.2514
#   monotonicity: 1.1850
#   smoothness: 1.0752
#   rel_smoothness: 0.1155
#   thermo: 0.0632
# Val   - Total: 0.2778, Physics: 2.7826
# LR: 0.000406
# Epoch [510/1000]
# Train - Total: 0.2341, Physics: 2.8232
# Physics Components:
#   cox_merz: 0.1530
#   angle: 0.2654
#   monotonicity: 1.1638
#   smoothness: 1.0616
#   rel_smoothness: 0.1156
#   thermo: 0.0637
# Val   - Total: 0.2768, Physics: 2.8940
# LR: 0.000397
# Epoch [520/1000]
# Train - Total: 0.2328, Physics: 2.8825
# Physics Components:
#   cox_merz: 0.1593
#   angle: 0.2653
#   monotonicity: 1.1934
#   smoothness: 1.0835
#   rel_smoothness: 0.1167
#   thermo: 0.0643
# Val   - Total: 0.2694, Physics: 2.8797
# LR: 0.000388
# Epoch [530/1000]
# Train - Total: 0.2211, Physics: 2.8838
# Physics Components:
#   cox_merz: 0.1552
#   angle: 0.2989
#   monotonicity: 1.1761
#   smoothness: 1.0669
#   rel_smoothness: 0.1227
#   thermo: 0.0639
# Val   - Total: 0.2685, Physics: 2.9727
# LR: 0.000378
# Epoch [540/1000]
# Train - Total: 0.2214, Physics: 2.8908
# Physics Components:
#   cox_merz: 0.1604
#   angle: 0.2611
#   monotonicity: 1.2056
#   smoothness: 1.0791
#   rel_smoothness: 0.1212
#   thermo: 0.0635
# Val   - Total: 0.2588, Physics: 3.0410
# LR: 0.000368
# Epoch [550/1000]
# Train - Total: 0.2126, Physics: 2.9081
# Physics Components:
#   cox_merz: 0.1568
#   angle: 0.2935
#   monotonicity: 1.1971
#   smoothness: 1.0724
#   rel_smoothness: 0.1220
#   thermo: 0.0663
# Val   - Total: 0.2555, Physics: 3.0692
# LR: 0.000358
# Epoch [560/1000]
# Train - Total: 0.2089, Physics: 2.9461
# Physics Components:
#   cox_merz: 0.1588
#   angle: 0.3049
#   monotonicity: 1.2039
#   smoothness: 1.0887
#   rel_smoothness: 0.1237
#   thermo: 0.0660
# Val   - Total: 0.2499, Physics: 2.9989
# LR: 0.000348
# Epoch [570/1000]
# Train - Total: 0.1996, Physics: 2.8363
# Physics Components:
#   cox_merz: 0.1551
#   angle: 0.2884
#   monotonicity: 1.1639
#   smoothness: 1.0432
#   rel_smoothness: 0.1205
#   thermo: 0.0651
# Val   - Total: 0.2497, Physics: 3.1595
# LR: 0.000338
# Epoch [580/1000]
# Train - Total: 0.1988, Physics: 2.9285
# Physics Components:
#   cox_merz: 0.1552
#   angle: 0.3485
#   monotonicity: 1.1814
#   smoothness: 1.0461
#   rel_smoothness: 0.1302
#   thermo: 0.0670
# Val   - Total: 0.2354, Physics: 2.9899
# LR: 0.000327
# Epoch [590/1000]
# Train - Total: 0.1939, Physics: 3.0340
# Physics Components:
#   cox_merz: 0.1580
#   angle: 0.3404
#   monotonicity: 1.2363
#   smoothness: 1.1025
#   rel_smoothness: 0.1283
#   thermo: 0.0685
# Val   - Total: 0.2355, Physics: 3.1683
# LR: 0.000316
# Epoch [600/1000]
# Train - Total: 0.1888, Physics: 3.0732
# Physics Components:
#   cox_merz: 0.1579
#   angle: 0.3886
#   monotonicity: 1.2277
#   smoothness: 1.0986
#   rel_smoothness: 0.1328
#   thermo: 0.0676
# Val   - Total: 0.2304, Physics: 2.9775
# LR: 0.000306
# Epoch [610/1000]
# Train - Total: 0.1857, Physics: 2.9992
# Physics Components:
#   cox_merz: 0.1621
#   angle: 0.3641
#   monotonicity: 1.2057
#   smoothness: 1.0703
#   rel_smoothness: 0.1290
#   thermo: 0.0679
# Val   - Total: 0.2249, Physics: 3.2010
# LR: 0.000295
# Epoch [620/1000]
# Train - Total: 0.1856, Physics: 3.1321
# Physics Components:
#   cox_merz: 0.1601
#   angle: 0.4113
#   monotonicity: 1.2363
#   smoothness: 1.1167
#   rel_smoothness: 0.1378
#   thermo: 0.0699
# Val   - Total: 0.2217, Physics: 3.1108
# LR: 0.000284
# Epoch [630/1000]
# Train - Total: 0.1720, Physics: 3.1150
# Physics Components:
#   cox_merz: 0.1605
#   angle: 0.4014
#   monotonicity: 1.2356
#   smoothness: 1.1132
#   rel_smoothness: 0.1356
#   thermo: 0.0688
# Val   - Total: 0.2145, Physics: 3.1920
# LR: 0.000272
# Epoch [640/1000]
# Train - Total: 0.1671, Physics: 3.1861
# Physics Components:
#   cox_merz: 0.1645
#   angle: 0.4453
#   monotonicity: 1.2557
#   smoothness: 1.1119
#   rel_smoothness: 0.1380
#   thermo: 0.0709
# Val   - Total: 0.2084, Physics: 3.1755
# LR: 0.000261
# Epoch [650/1000]
# Train - Total: 0.1675, Physics: 3.2050
# Physics Components:
#   cox_merz: 0.1633
#   angle: 0.4604
#   monotonicity: 1.2538
#   smoothness: 1.1153
#   rel_smoothness: 0.1422
#   thermo: 0.0700
# Val   - Total: 0.2057, Physics: 3.2265
# LR: 0.000250
# Epoch [660/1000]
# Train - Total: 0.1565, Physics: 3.1917
# Physics Components:
#   cox_merz: 0.1600
#   angle: 0.4901
#   monotonicity: 1.2319
#   smoothness: 1.0975
#   rel_smoothness: 0.1404
#   thermo: 0.0718
# Val   - Total: 0.2004, Physics: 3.3199
# LR: 0.000239
# Epoch [670/1000]
# Train - Total: 0.1562, Physics: 3.2896
# Physics Components:
#   cox_merz: 0.1652
#   angle: 0.5285
#   monotonicity: 1.2476
#   smoothness: 1.1245
#   rel_smoothness: 0.1495
#   thermo: 0.0743
# Val   - Total: 0.1954, Physics: 3.3539
# LR: 0.000228
# Epoch [680/1000]
# Train - Total: 0.1576, Physics: 3.1602
# Physics Components:
#   cox_merz: 0.1587
#   angle: 0.4810
#   monotonicity: 1.2196
#   smoothness: 1.0904
#   rel_smoothness: 0.1418
#   thermo: 0.0688
# Val   - Total: 0.1909, Physics: 3.3484
# LR: 0.000216
# Epoch [690/1000]
# Train - Total: 0.1495, Physics: 3.3534
# Physics Components:
#   cox_merz: 0.1589
#   angle: 0.5929
#   monotonicity: 1.2492
#   smoothness: 1.1307
#   rel_smoothness: 0.1492
#   thermo: 0.0725
# Val   - Total: 0.1854, Physics: 3.4283
# LR: 0.000205
# Epoch [700/1000]
# Train - Total: 0.1392, Physics: 3.3371
# Physics Components:
#   cox_merz: 0.1633
#   angle: 0.5937
#   monotonicity: 1.2407
#   smoothness: 1.1176
#   rel_smoothness: 0.1474
#   thermo: 0.0744
# Val   - Total: 0.1820, Physics: 3.3912
# LR: 0.000194
# Epoch [710/1000]
# Train - Total: 0.1304, Physics: 3.4254
# Physics Components:
#   cox_merz: 0.1619
#   angle: 0.6362
#   monotonicity: 1.2677
#   smoothness: 1.1325
#   rel_smoothness: 0.1541
#   thermo: 0.0729
# Val   - Total: 0.1756, Physics: 3.5809
# LR: 0.000183
# Epoch [720/1000]
# Train - Total: 0.1292, Physics: 3.4242
# Physics Components:
#   cox_merz: 0.1636
#   angle: 0.6306
#   monotonicity: 1.2653
#   smoothness: 1.1385
#   rel_smoothness: 0.1505
#   thermo: 0.0756
# Val   - Total: 0.1718, Physics: 3.5581
# LR: 0.000173
# Epoch [730/1000]
# Train - Total: 0.1297, Physics: 3.5035
# Physics Components:
#   cox_merz: 0.1668
#   angle: 0.6102
#   monotonicity: 1.3169
#   smoothness: 1.1792
#   rel_smoothness: 0.1545
#   thermo: 0.0759
# Val   - Total: 0.1678, Physics: 3.6292
# LR: 0.000162
# Epoch [740/1000]
# Train - Total: 0.1207, Physics: 3.6304
# Physics Components:
#   cox_merz: 0.1635
#   angle: 0.7375
#   monotonicity: 1.3162
#   smoothness: 1.1859
#   rel_smoothness: 0.1517
#   thermo: 0.0756
# Val   - Total: 0.1614, Physics: 3.6175
# LR: 0.000152
# Epoch [750/1000]
# Train - Total: 0.1142, Physics: 3.6040
# Physics Components:
#   cox_merz: 0.1606
#   angle: 0.8503
#   monotonicity: 1.2476
#   smoothness: 1.1137
#   rel_smoothness: 0.1562
#   thermo: 0.0756
# Val   - Total: 0.1585, Physics: 3.8042
# LR: 0.000141
# Epoch [760/1000]
# Train - Total: 0.1109, Physics: 3.6802
# Physics Components:
#   cox_merz: 0.1703
#   angle: 0.8216
#   monotonicity: 1.2939
#   smoothness: 1.1560
#   rel_smoothness: 0.1622
#   thermo: 0.0761
# Val   - Total: 0.1563, Physics: 3.8121
# LR: 0.000131
# Epoch [770/1000]
# Train - Total: 0.1089, Physics: 3.7375
# Physics Components:
#   cox_merz: 0.1637
#   angle: 0.8595
#   monotonicity: 1.3008
#   smoothness: 1.1713
#   rel_smoothness: 0.1639
#   thermo: 0.0783
# Val   - Total: 0.1507, Physics: 3.9044
# LR: 0.000122
# Epoch [780/1000]
# Train - Total: 0.1097, Physics: 3.7371
# Physics Components:
#   cox_merz: 0.1676
#   angle: 0.8006
#   monotonicity: 1.3349
#   smoothness: 1.1925
#   rel_smoothness: 0.1647
#   thermo: 0.0768
# Val   - Total: 0.1464, Physics: 3.9266
# LR: 0.000112
# Epoch [790/1000]
# Train - Total: 0.1003, Physics: 3.8872
# Physics Components:
#   cox_merz: 0.1621
#   angle: 1.0735
#   monotonicity: 1.2667
#   smoothness: 1.1343
#   rel_smoothness: 0.1710
#   thermo: 0.0796
# Val   - Total: 0.1409, Physics: 4.0586
# LR: 0.000103
# Epoch [800/1000]
# Train - Total: 0.0960, Physics: 3.8413
# Physics Components:
#   cox_merz: 0.1662
#   angle: 1.0139
#   monotonicity: 1.2769
#   smoothness: 1.1374
#   rel_smoothness: 0.1686
#   thermo: 0.0783
# Val   - Total: 0.1389, Physics: 4.2706
# LR: 0.000094
# Epoch [810/1000]
# Train - Total: 0.0961, Physics: 3.9862
# Physics Components:
#   cox_merz: 0.1615
#   angle: 1.1784
#   monotonicity: 1.2672
#   smoothness: 1.1314
#   rel_smoothness: 0.1696
#   thermo: 0.0782
# Val   - Total: 0.1334, Physics: 4.4321
# LR: 0.000085
# Epoch [820/1000]
# Train - Total: 0.0917, Physics: 4.2344
# Physics Components:
#   cox_merz: 0.1712
#   angle: 1.2461
#   monotonicity: 1.3457
#   smoothness: 1.2154
#   rel_smoothness: 0.1766
#   thermo: 0.0794
# Val   - Total: 0.1303, Physics: 4.3929
# LR: 0.000077
# Epoch [830/1000]
# Train - Total: 0.0866, Physics: 4.4630
# Physics Components:
#   cox_merz: 0.1725
#   angle: 1.4239
#   monotonicity: 1.3700
#   smoothness: 1.2357
#   rel_smoothness: 0.1814
#   thermo: 0.0795
# Val   - Total: 0.1262, Physics: 4.6125
# LR: 0.000069
# Epoch [840/1000]
# Train - Total: 0.0846, Physics: 4.4189
# Physics Components:
#   cox_merz: 0.1708
#   angle: 1.4122
#   monotonicity: 1.3537
#   smoothness: 1.2161
#   rel_smoothness: 0.1860
#   thermo: 0.0802
# Val   - Total: 0.1232, Physics: 4.8145
# LR: 0.000062
# Epoch [850/1000]
# Train - Total: 0.0786, Physics: 4.6244
# Physics Components:
#   cox_merz: 0.1679
#   angle: 1.6817
#   monotonicity: 1.3266
#   smoothness: 1.1832
#   rel_smoothness: 0.1830
#   thermo: 0.0820
# Val   - Total: 0.1190, Physics: 5.0880
# LR: 0.000055
# Epoch [860/1000]
# Train - Total: 0.0768, Physics: 4.9723
# Physics Components:
#   cox_merz: 0.1652
#   angle: 1.9521
#   monotonicity: 1.3528
#   smoothness: 1.2266
#   rel_smoothness: 0.1933
#   thermo: 0.0823
# Val   - Total: 0.1145, Physics: 5.2153
# LR: 0.000048
# Epoch [870/1000]
# Train - Total: 0.0687, Physics: 5.1922
# Physics Components:
#   cox_merz: 0.1649
#   angle: 2.2379
#   monotonicity: 1.3280
#   smoothness: 1.1915
#   rel_smoothness: 0.1866
#   thermo: 0.0832
# Val   - Total: 0.1125, Physics: 5.4378
# LR: 0.000041
# Epoch [880/1000]
# Train - Total: 0.0685, Physics: 5.2916
# Physics Components:
#   cox_merz: 0.1688
#   angle: 2.2999
#   monotonicity: 1.3453
#   smoothness: 1.2021
#   rel_smoothness: 0.1944
#   thermo: 0.0812
# Val   - Total: 0.1079, Physics: 5.7148
# LR: 0.000035
# Epoch [890/1000]
# Train - Total: 0.0665, Physics: 5.4481
# Physics Components:
#   cox_merz: 0.1694
#   angle: 2.4387
#   monotonicity: 1.3528
#   smoothness: 1.2101
#   rel_smoothness: 0.1943
#   thermo: 0.0827
# Val   - Total: 0.1023, Physics: 6.2976
# LR: 0.000030
# Epoch [900/1000]
# Train - Total: 0.0604, Physics: 6.1137
# Physics Components:
#   cox_merz: 0.1597
#   angle: 3.1617
#   monotonicity: 1.3219
#   smoothness: 1.1903
#   rel_smoothness: 0.1977
#   thermo: 0.0823
# Val   - Total: 0.1006, Physics: 6.3807
# LR: 0.000025
# Epoch [910/1000]
# Train - Total: 0.0560, Physics: 6.5553
# Physics Components:
#   cox_merz: 0.1679
#   angle: 3.5248
#   monotonicity: 1.3640
#   smoothness: 1.2138
#   rel_smoothness: 0.2018
#   thermo: 0.0830
# Val   - Total: 0.0979, Physics: 7.1921
# LR: 0.000020
# Epoch [920/1000]
# Train - Total: 0.0544, Physics: 7.3192
# Physics Components:
#   cox_merz: 0.1681
#   angle: 4.2766
#   monotonicity: 1.3685
#   smoothness: 1.2178
#   rel_smoothness: 0.2030
#   thermo: 0.0852
# Val   - Total: 0.0945, Physics: 7.5956
# LR: 0.000016
# Epoch [930/1000]
# Train - Total: 0.0505, Physics: 7.9136
# Physics Components:
#   cox_merz: 0.1612
#   angle: 4.9680
#   monotonicity: 1.3178
#   smoothness: 1.1826
#   rel_smoothness: 0.1992
#   thermo: 0.0848
# Val   - Total: 0.0921, Physics: 8.5021
# LR: 0.000012
# Epoch [940/1000]
# Train - Total: 0.0526, Physics: 8.6673
# Physics Components:
#   cox_merz: 0.1679
#   angle: 5.5879
#   monotonicity: 1.3830
#   smoothness: 1.2285
#   rel_smoothness: 0.2135
#   thermo: 0.0864
# Val   - Total: 0.0881, Physics: 9.4846
# LR: 0.000009
# Epoch [950/1000]
# Train - Total: 0.0487, Physics: 9.6677
# Physics Components:
#   cox_merz: 0.1615
#   angle: 6.7309
#   monotonicity: 1.3076
#   smoothness: 1.1688
#   rel_smoothness: 0.2142
#   thermo: 0.0846
# Val   - Total: 0.0846, Physics: 11.1826
# LR: 0.000006
# Epoch [960/1000]
# Train - Total: 0.0413, Physics: 11.4976
# Physics Components:
#   cox_merz: 0.1662
#   angle: 8.3241
#   monotonicity: 1.4224
#   smoothness: 1.2773
#   rel_smoothness: 0.2214
#   thermo: 0.0862
# Val   - Total: 0.0816, Physics: 12.1980
# LR: 0.000004
# Epoch [970/1000]
# Train - Total: 0.0422, Physics: 12.7380
# Physics Components:
#   cox_merz: 0.1668
#   angle: 9.6551
#   monotonicity: 1.3763
#   smoothness: 1.2312
#   rel_smoothness: 0.2220
#   thermo: 0.0865
# Val   - Total: 0.0790, Physics: 14.0940
# LR: 0.000002
# Epoch [980/1000]
# Train - Total: 0.0395, Physics: 13.4295
# Physics Components:
#   cox_merz: 0.1677
#   angle: 10.3053
#   monotonicity: 1.3957
#   smoothness: 1.2518
#   rel_smoothness: 0.2211
#   thermo: 0.0878
# Val   - Total: 0.0774, Physics: 14.2412
# LR: 0.000001
# Epoch [990/1000]
# Train - Total: 0.0353, Physics: 14.0465
# Physics Components:
#   cox_merz: 0.1644
#   angle: 11.0152
#   monotonicity: 1.3514
#   smoothness: 1.2091
#   rel_smoothness: 0.2192
#   thermo: 0.0872
# Val   - Total: 0.0755, Physics: 16.2582
# LR: 0.000000
# Epoch [1000/1000]
# Train - Total: 0.0385, Physics: 15.0845
# Physics Components:
#   cox_merz: 0.1667
#   angle: 11.9055
#   monotonicity: 1.4190
#   smoothness: 1.2731
#   rel_smoothness: 0.2333
#   thermo: 0.0869
# Val   - Total: 0.0755, Physics: 15.5964
# LR: 0.000000

# %%
# 模型评估函数
def evaluate_model(model: RheologyPINN, dataset: RheologyDataset):
    """评估模型性能
    
    Args:
        model: 训练好的PINN模型
        dataset: 数据集对象
    """
    model.eval()
    with torch.no_grad():
        # 在验证集上进行预测
        y_pred = model(dataset.X_val)
        y_true = dataset.y_val
        
        # 转换回原始尺度
        y_pred_orig = dataset.inverse_transform_y(y_pred)
        y_true_orig = dataset.inverse_transform_y(y_true)
        
        # 计算R²分数
        from sklearn.metrics import r2_score
        r2_g1 = r2_score(y_true_orig[:, 0], y_pred_orig[:, 0])
        r2_g2 = r2_score(y_true_orig[:, 1], y_pred_orig[:, 1])
        
        print(f"\nR² 分数:")
        print(f"G' (储能模量): {r2_g1:.4f}")
        print(f"G\" (损耗模量): {r2_g2:.4f}")
        
        # 绘制预测vs实际值的散点图
        plt.figure(figsize=(12, 5))
        
        plt.subplot(1, 2, 1)
        plt.scatter(y_true_orig[:, 0], y_pred_orig[:, 0], alpha=0.5)
        plt.plot([y_true_orig[:, 0].min(), y_true_orig[:, 0].max()],
                 [y_true_orig[:, 0].min(), y_true_orig[:, 0].max()],
                 'r--', label='Perfect Prediction')
        plt.xlabel('True G\' (Pa)')
        plt.ylabel('Predicted G\' (Pa)')
        plt.title(f'G\' Predictions (R² = {r2_g1:.4f})')
        plt.legend()
        
        plt.subplot(1, 2, 2)
        plt.scatter(y_true_orig[:, 1], y_pred_orig[:, 1], alpha=0.5)
        plt.plot([y_true_orig[:, 1].min(), y_true_orig[:, 1].max()],
                 [y_true_orig[:, 1].min(), y_true_orig[:, 1].max()],
                 'r--', label='Perfect Prediction')
        plt.xlabel('True G" (Pa)')
        plt.ylabel('Predicted G" (Pa)')
        plt.title(f'G" Predictions (R² = {r2_g2:.4f})')
        plt.legend()
        
        plt.tight_layout()
        plt.show()

# 评估模型
evaluate_model(model, dataset)
# Out:
# R² 分数:
# G' (储能模量): 0.9333
# G" (损耗模量): 0.9627

# %%
# 预测新样本的函数
def predict_rheology(model: RheologyPINN, 
                    sample_data: pd.DataFrame, 
                    dataset: RheologyDataset,
                    with_uncertainty: bool = True) -> pd.DataFrame:
    """预测新样本的流变性能
    
    Args:
        model: 训练好的PINN模型
        sample_data: 包含新样本数据的DataFrame
        dataset: 数据集对象
        with_uncertainty: 是否计算预测不确定性
        
    Returns:
        预测结果DataFrame
    """
    # 特征工程
    processed_data = sample_data.copy()
    
    # 基本特征工程
    processed_data['aspect_ratio'] = processed_data['Length_nm'] / processed_data['Width_nm']
    processed_data['log_freq'] = np.log10(processed_data['Freq_rad_s'])
    
    # 分子量相关特征
    if 'Mw' in processed_data.columns and 'Mn' in processed_data.columns:
        processed_data['PDI'] = processed_data['Mw'] / processed_data['Mn']
        processed_data['log_Mw'] = np.log10(processed_data['Mw'])
        processed_data['log_Mn'] = np.log10(processed_data['Mn'])
    else:
        processed_data['Mw'] = 0
        processed_data['Mn'] = 0
        processed_data['PDI'] = 1
        processed_data['log_Mw'] = 0
        processed_data['log_Mn'] = 0
    
    # 浓度特征
    if 'c' in processed_data.columns:
        processed_data['log_c'] = np.log10(processed_data['c'])
    else:
        processed_data['c'] = 0
        processed_data['log_c'] = 0
    
    # WLF时温等效性特征
    T_ref = 25  # 参考温度
    C1 = 8.86   # WLF参数
    C2 = 101.6  # WLF参数
    processed_data['aT'] = 10 ** (-C1 * (processed_data['Temp_C'] - T_ref) / 
                                 (C2 + processed_data['Temp_C'] - T_ref))
    
    # 温度相关特征
    processed_data['temp_inv'] = 1 / (processed_data['Temp_C'] + 273.15)
    processed_data['T_x_aspect'] = processed_data['Temp_C'] * processed_data['aspect_ratio']
    
    # 准备输入特征
    X_new = dataset.scaler_X.transform(processed_data[dataset.feature_cols])
    X_new = torch.FloatTensor(X_new).to(device)
    
    # 预测
    model.eval()
    if with_uncertainty:
        # 使用Monte Carlo Dropout进行带不确定性的预测
        mean_pred, std_pred = model.predict_with_uncertainty(X_new, MC_SAMPLES)
        y_pred = mean_pred
        
        # 转换预测值和不确定性范围
        y_pred_orig = dataset.inverse_transform_y(y_pred)
        y_upper = dataset.inverse_transform_y(y_pred + 2 * std_pred)  # 95% 置信区间
        y_lower = dataset.inverse_transform_y(y_pred - 2 * std_pred)
        
        # 添加预测结果和不确定性
        results = processed_data.copy()
        results['G1_Pa_pred'] = y_pred_orig[:, 0]
        results['G2_Pa_pred'] = y_pred_orig[:, 1]
        results['G1_Pa_lower'] = y_lower[:, 0]
        results['G1_Pa_upper'] = y_upper[:, 0]
        results['G2_Pa_lower'] = y_lower[:, 1]
        results['G2_Pa_upper'] = y_upper[:, 1]
    else:
        # 不计算不确定性的简单预测
        with torch.no_grad():
            y_pred = model(X_new)
            y_pred_orig = dataset.inverse_transform_y(y_pred)
            
            results = processed_data.copy()
            results['G1_Pa_pred'] = y_pred_orig[:, 0]
            results['G2_Pa_pred'] = y_pred_orig[:, 1]
    
    # 确保G'和G"随频率单调递增
    def ensure_monotonicity(df):
        # 按频率排序
        df = df.sort_values('Freq_rad_s')
        
        # 为G'和G"创建单调递增的序列
        for col in ['G1_Pa_pred', 'G2_Pa_pred']:
            values = df[col].values
            for i in range(1, len(values)):
                if values[i] < values[i-1]:
                    # 如果当前值小于前一个值，使用插值进行调整
                    if i < len(values) - 1:
                        # 如果不是最后一个点，使用线性插值
                        slope = (values[i+1] - values[i-1]) / 2
                        values[i] = values[i-1] + slope
                    else:
                        # 如果是最后一个点，确保大于前一个值
                        values[i] = values[i-1] * 1.05  # 增加5%
            df[col] = values
        return df
    
    # 应用单调性约束
    results = results.groupby('Sample_ID').apply(ensure_monotonicity).reset_index(drop=True)
    
    # 计算初始tan_delta
    results['tan_delta_pred'] = results['G2_Pa_pred'] / results['G1_Pa_pred']
    
    # 调整超出范围的tan_delta值
    def adjust_moduli(row):
        tan_delta = row['tan_delta_pred']
        if tan_delta < 0.1 or tan_delta > 4.0:
            # 计算几何平均值以保持模量的相对大小关系
            geometric_mean = np.sqrt(row['G1_Pa_pred'] * row['G2_Pa_pred'])
            
            if tan_delta < 0.1:
                # 如果tan_delta太小，调整G"
                new_tan_delta = 0.1
                new_G1 = geometric_mean * np.sqrt(1/new_tan_delta)
                new_G2 = geometric_mean * np.sqrt(new_tan_delta)
            else:
                # 如果tan_delta太大，调整G'
                new_tan_delta = 4.0
                new_G1 = geometric_mean * np.sqrt(1/new_tan_delta)
                new_G2 = geometric_mean * np.sqrt(new_tan_delta)
            
            return pd.Series({
                'G1_Pa_pred': new_G1,
                'G2_Pa_pred': new_G2,
                'tan_delta_pred': new_tan_delta
            })
        return pd.Series({
            'G1_Pa_pred': row['G1_Pa_pred'],
            'G2_Pa_pred': row['G2_Pa_pred'],
            'tan_delta_pred': tan_delta
        })
    
    # 应用调整
    adjusted = results.apply(adjust_moduli, axis=1)
    results[['G1_Pa_pred', 'G2_Pa_pred', 'tan_delta_pred']] = adjusted
    
    # 如果有不确定性估计，也要相应调整边界
    if 'G1_Pa_lower' in results.columns:
        def adjust_bounds(row):
            # 调整下界
            tan_delta_lower = row['G2_Pa_lower'] / row['G1_Pa_upper']  # 最小tan_delta
            if tan_delta_lower < 0.1:
                scale = np.sqrt(0.1 / tan_delta_lower)
                row['G2_Pa_lower'] *= scale
                row['G1_Pa_upper'] /= scale
            
            # 调整上界
            tan_delta_upper = row['G2_Pa_upper'] / row['G1_Pa_lower']  # 最大tan_delta
            if tan_delta_upper > 5.0:
                scale = np.sqrt(5.0 / tan_delta_upper)
                row['G2_Pa_upper'] *= scale
                row['G1_Pa_lower'] /= scale
            
            return row
        
        results = results.apply(adjust_bounds, axis=1)
    
    return results

# 示例：预测新样本
new_samples = pd.DataFrame({
    "Sample_ID": ["411c"] * 30,
    "Length_nm": [300] * 30,
    "Width_nm": [20.94] * 30,
    "Temp_C": [25] * 30,
    "c": [0.06] * 30,
    "Mn": [12230000] * 30,
    "Mw": [12590000] * 30,
    "Freq_rad_s": [0.1, 0.127, 0.161, 0.204, 0.259, 0.329, 0.418, 0.530, 0.672, 0.853, 1.08, 1.37, 1.74, 2.21, 2.81, 3.56, 
                   4.52, 5.74, 7.28, 9.24, 11.7, 14.9, 18.9, 24, 30.4, 38.6, 48.9, 62.1, 78.8, 100]
})

predictions = predict_rheology(model, new_samples, dataset)

# 可视化预测结果
def plot_predictions(predictions: pd.DataFrame, sample_id: str):
    """可视化预测结果
    
    Args:
        predictions: 预测结果DataFrame
        sample_id: 样品ID
    """
    sample_data = predictions[predictions['Sample_ID'] == sample_id]
    
    plt.figure(figsize=(15, 5))
    
    # G' 和 G" 随频率的变化
    plt.subplot(1, 3, 1)
    plt.loglog(sample_data['Freq_rad_s'], sample_data['G1_Pa_pred'], 'o-', label="G'")
    plt.loglog(sample_data['Freq_rad_s'], sample_data['G2_Pa_pred'], 's-', label='G"')
    if 'G1_Pa_lower' in sample_data.columns:
        plt.fill_between(sample_data['Freq_rad_s'], 
                        sample_data['G1_Pa_lower'],
                        sample_data['G1_Pa_upper'],
                        alpha=0.2)
        plt.fill_between(sample_data['Freq_rad_s'],
                        sample_data['G2_Pa_lower'],
                        sample_data['G2_Pa_upper'],
                        alpha=0.2)
    plt.xlabel('Frequency (rad/s)')
    plt.ylabel('G\', G" (Pa)')
    plt.title(f'Sample {sample_id}: G\' and G" vs Frequency')
    plt.legend()
    plt.grid(True)
    
    # tan(δ) 随频率的变化
    plt.subplot(1, 3, 2)
    plt.semilogx(sample_data['Freq_rad_s'], sample_data['tan_delta_pred'], 'o-')
    plt.axhline(y=0.1, color='r', linestyle='--', alpha=0.5)
    plt.axhline(y=4.0, color='r', linestyle='--', alpha=0.5)
    plt.xlabel('Frequency (rad/s)')
    plt.ylabel('tan(δ)')
    plt.title(f'Sample {sample_id}: tan(δ) vs Frequency')
    plt.grid(True)
    
    # Cole-Cole图
    plt.subplot(1, 3, 3)
    plt.plot(sample_data['G1_Pa_pred'], sample_data['G2_Pa_pred'], 'o-')
    plt.xlabel('G\' (Pa)')
    plt.ylabel('G" (Pa)')
    plt.title('Cole-Cole Plot')
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# 为每个新样本绘制预测结果
for sample_id in predictions['Sample_ID'].unique():
    plot_predictions(predictions, sample_id)

# 打印预测结果
print("\n新样本预测结果:")
print(predictions[['Sample_ID', 'Length_nm', 'Width_nm', 'Temp_C', 
                  'Freq_rad_s', 'G1_Pa_pred', 'G2_Pa_pred', 'tan_delta_pred']])
# Out:
# /var/folders/74/b8381_dj5kz02s63kv277jqh0000gn/T/ipykernel_3516/1970952962.py:110: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   results = results.groupby('Sample_ID').apply(ensure_monotonicity).reset_index(drop=True)
# 新样本预测结果:
#    Sample_ID  Length_nm  Width_nm  Temp_C  Freq_rad_s  G1_Pa_pred  G2_Pa_pred  \
# 0       411c        300     20.94      25       0.100    0.070060    0.270105
# 1       411c        300     20.94      25       0.127    0.086451    0.161418
# 2       411c        300     20.94      25       0.161    0.158967    0.204492
# 3       411c        300     20.94      25       0.204    0.231484    0.247566
# 4       411c        300     20.94      25       0.259    0.433490    0.512260
# 5       411c        300     20.94      25       0.329    0.635496    0.776954
# 6       411c        300     20.94      25       0.418    2.332158    2.544621
# 7       411c        300     20.94      25       0.530    6.315156    4.966656
# 8       411c        300     20.94      25       0.672   11.125202    8.431071
# 9       411c        300     20.94      25       0.853   16.334471   11.028885
# 10      411c        300     20.94      25       1.080   11.778776    8.799711
# 11      411c        300     20.94      25       1.370    8.205900    6.515842
# 12      411c        300     20.94      25       1.740    7.044388    5.503716
# 13      411c        300     20.94      25       2.210    6.580114    6.084905
# 14      411c        300     20.94      25       2.810    7.213319    6.666093
# 15      411c        300     20.94      25       3.560    7.846524    8.722699
# 16      411c        300     20.94      25       4.520    6.562262   11.321322
# 17      411c        300     20.94      25       5.740    4.599959   12.609434
# 18      411c        300     20.94      25       7.280    3.367958   11.082531
# 19      411c        300     20.94      25       9.240    3.095751   11.489009
# 20      411c        300     20.94      25      11.700    3.169325   11.895487
# 21      411c        300     20.94      25      14.900    3.242900   12.849000
# 22      411c        300     20.94      25      18.900    4.302383   17.209532
# 23      411c        300     20.94      25      24.000   10.582929   26.410814
# 24      411c        300     20.94      25      30.400   22.047464   39.347275
# 25      411c        300     20.94      25      38.600   86.390335   61.157307
# 26      411c        300     20.94      25      48.900   56.641724   55.844666
# 27      411c        300     20.94      25      62.100   39.967857   50.097210
# 28      411c        300     20.94      25      78.800   23.977854   45.319103
# 29      411c        300     20.94      25     100.000   25.176744   47.585056
#
#     tan_delta_pred
# 0         3.855351
# 1         1.867174
# 2         1.286380
# 3         1.069475
# 4         1.181712
# 5         1.222594
# 6         1.091101
# 7         0.786466
# 8         0.757835
# 9         0.675191
# 10        0.747082
# 11        0.794044
# 12        0.781291
# 13        0.924742
# 14        0.924137
# 15        1.111664
# 16        1.725217
# 17        2.741206
# 18        3.290579
# 19        3.711219
# 20        3.753318
# 21        3.962195
# 22        4.000000
# 23        2.495605
# 24        1.784662
# 25        0.707918
# 26        0.985928
# 27        1.253438
# 28        1.890040
# 29        1.890040
